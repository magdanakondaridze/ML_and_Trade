# %%
import requests
r = requests.get('https://www.wto.org/english/tratop_e/dispu_e/cases_e/ds462_e.htm')

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge">
# <meta http-equiv="Content-Type"
# content="text/html; charset=iso-8859-1">
# <meta name="description"
# content="WTO | dispute settlement - the disputes - DS">
# <meta name="keywords"
# content="www.wto.org, World Trade Organization, world trade, trade disputes, #TradeDisputes,  ministerial, WTO publications, intellectual property,
# government procurement, goods, services, economic research, Statistics,

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('p')

# %%
len(results)
# Out:
# 23

# %%
results[0:3]
# Out:
# [<p class="menudefaulttext"><a class="menudefaulttext" href="http://www.wto.org/index.htm">Home</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/thewto_e/thewto_e.htm">About WTO</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/news_e/news_e.htm">News &amp; events</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/tratop_e/tratop_e.htm">Trade topics</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/thewto_e/whatis_e/tif_e/org6_e.htm">WTO membership</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/res_e/res_e.htm">Documents &amp; resources</a>  |  <a class="menudefaulttext" href="http://www.wto.org/english/forums_e/forums_e.htm">External relations</a></p>,
# ...

# %%
results[-1]
# Out:
# <span class="__cf_email__" data-cfemail="81f6e4e3ece0f2f5e4f3c1f6f5eeafeef3e6">[email protected]</span>
